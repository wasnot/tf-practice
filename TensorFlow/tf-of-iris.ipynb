# %%
import tensorflow

import sys
sys.path.append('../../tf_models/samples/core/get_started/')
import iris_data

# %%
(train_feature, train_label), (test_feature, test_label) = iris_data.load_data()

# %%
test_feature
# Out:
#     SepalLength  SepalWidth  PetalLength  PetalWidth
# 0           5.9         3.0          4.2         1.5
# 1           6.9         3.1          5.4         2.1
# 2           5.1         3.3          1.7         0.5
# 3           6.0         3.4          4.5         1.6
# 4           5.5         2.5          4.0         1.3
# 5           6.2         2.9          4.3         1.3
# 6           5.5         4.2          1.4         0.2
# 7           6.3         2.8          5.1         1.5
# 8           5.6         3.0          4.1         1.3
# 9           6.7         2.5          5.8         1.8
# 10          7.1         3.0          5.9         2.1
# 11          4.3         3.0          1.1         0.1
# 12          5.6         2.8          4.9         2.0
# 13          5.5         2.3          4.0         1.3
# 14          6.0         2.2          4.0         1.0
# 15          5.1         3.5          1.4         0.2
# 16          5.7         2.6          3.5         1.0
# ...

# %%
tensorflow.__version__
# Out:
# '1.4.0'

# %%
import antigravity
